# %%
print("This is working")
# Out:
# This is working

# %%
type("Thanks")
# Out:
# str

# %%
a= 4
b= 7
print(a&b)  # Bitwise AND
print(a|b)  # Bitwise OR
print(a^b)  # Bitwise XOR
# Out:
# 4
# 7
# 3
